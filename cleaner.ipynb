# %%
import pandas as pd

# %%
data = pd.read_csv("database.csv", sep=",")

# %%
data.head(50)
# Out:
#            Source  Locality Type of property Subtype of property      Price  \
# 0   logic-immo.be      2970        apartment                 NaN   319799.0
# 1   logic-immo.be      2970        apartment                 NaN   291999.0
# 2   logic-immo.be      2970        apartment                 NaN   764999.0
# 3   logic-immo.be      2970        apartment                 NaN   660264.0
# 4   logic-immo.be      3200        apartment                 NaN   294999.0
# 5   logic-immo.be      8211        apartment                 NaN   257999.0
# 6   logic-immo.be      8211        apartment                 NaN   233999.0
# 7   logic-immo.be      2630        apartment                 NaN   329899.0
# 8   logic-immo.be      2630        apartment                 NaN   258999.0
# 9   logic-immo.be      2630        apartment           penthouse   359899.0
# 10  logic-immo.be      1790        apartment            building        NaN
# ...

# %%
del data["Unnamed: 0"]

# %%
data.iloc[142]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73547 entries, 0 to 73546
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Source                            73547 non-null  object
#  1   Locality                          73547 non-null  int64
#  2   Type of property                  73167 non-null  object
#  3   Subtype of property               14730 non-null  object
#  4   Price                             72543 non-null  float64
#  5   Type of sale                      73547 non-null  object
#  6   Number of rooms                   72643 non-null  float64
#  7   Area                              62275 non-null  float64
#  8   Fully equipped kitchen            73547 non-null  float64
#  9   Furnished                         53506 non-null  float64
#  10  Open fire                         73547 non-null  float64
# ...

# %%
data["Swimming pool"].value_counts()
# Out:
# 0.0    72458
# 1.0     1089
# Name: Swimming pool, dtype: int64

# %%
data["Number of facades"].value_counts()
# Out:
# 2.0     17418
# 4.0      9259
# 3.0      8820
# 1.0       411
# 6.0         2
# 7.0         1
# 10.0        1
# Name: Number of facades, dtype: int64

# %%
data["Open fire"].value_counts()
# Out:
# 0.0    70929
# 1.0     2618
# Name: Open fire, dtype: int64

# %%
data["Fully equipped kitchen"].value_counts()
# Out:
# 0.0    64630
# 1.0     8917
# Name: Fully equipped kitchen, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73547 entries, 0 to 73546
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Source                            73547 non-null  object
#  1   Locality                          73547 non-null  int64
#  2   Type of property                  73167 non-null  object
#  3   Subtype of property               14730 non-null  object
#  4   Price                             72543 non-null  float64
#  5   Type of sale                      73547 non-null  object
#  6   Number of rooms                   72643 non-null  float64
#  7   Area                              62275 non-null  float64
#  8   Fully equipped kitchen            73547 non-null  float64
#  9   Furnished                         53506 non-null  float64
#  10  Open fire                         73547 non-null  float64
# ...

# %%
data["State of the building"].value_counts()
# Out:
# good           31891
# to renovate     7206
# new             1432
# Name: State of the building, dtype: int64

# %%
data.iloc[142]
# Out:
# Source                              logic-immo.be
# Locality                                     1070
# Type of property                        apartment
# Subtype of property                           NaN
# Price                                      178999
# Type of sale                         regular sale
# Number of rooms                                 1
# Area                                           52
# Fully equipped kitchen                          0
# Furnished                                       0
# Open fire                                       0
# Terrace                                         1
# Terrace Area                                   30
# Garden                                          0
# Garden Area                                   NaN
# Surface of the land                           150
# Surface area of the plot of land              150
# Number of facades                             NaN
# Swimming pool                                   0
# ...

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73478 entries, 0 to 73546
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Source                            73478 non-null  object
#  1   Locality                          73478 non-null  int64
#  2   Type of property                  73098 non-null  object
#  3   Subtype of property               14721 non-null  object
#  4   Price                             72474 non-null  float64
#  5   Type of sale                      73478 non-null  object
#  6   Number of rooms                   72574 non-null  float64
#  7   Area                              62218 non-null  float64
#  8   Fully equipped kitchen            73478 non-null  float64
#  9   Furnished                         53452 non-null  float64
#  10  Open fire                         73478 non-null  float64
# ...

# %%
data["Locality"].value_counts().sort_values()
# Out:
# 4162       1
# 6441       1
# 6762       1
# 5541       1
# 8956       1
#         ...
# 1180    1137
# 8300    1219
# 9000    1280
# 1050    1280
# 8400    1416
# Name: Locality, Length: 1006, dtype: int64

# %%
data["Garden"].value_counts()
# Out:
# 0.0    55830
# 1.0    17648
# Name: Garden, dtype: int64

# %%
data.drop_duplicates(how="any")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-4a1b2a250e3d> in <module>
# ----> 1 data.drop_duplicates(how="any")
#
# TypeError: drop_duplicates() got an unexpected keyword argument 'how'

# %%
data["Type of property"].value_counts()
# Out:
# apartment    37201
# house        35897
# Name: Type of property, dtype: int64

# %%
filt = data["Type of property"] == "apartment"
data.loc[filt, "Number of facades"] = "NaN"
#data.groupby("Type of property")["Number of facades"].count().to_frame()
data.loc[filt, "Number of facades"].value_counts()
# Out:
# C:\Users\spolo\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# NaN    37201
# Name: Number of facades, dtype: int64

# %%
data["Commune"] = ["Brussel" if (x >= 1000 and x < 1300) else continue for x in data["Locality"]]
# Out:
#   File "<ipython-input-67-ce4c211cade2>", line 1
#     data["Commune"] = ["Brussel" if (x >= 1000 and x < 1300) else continue for x in data["Locality"]]
#                                                                   ^
# SyntaxError: invalid syntax

# %%
def change_to_province(code):
    if code >= 1000 and code < 1300:
        return "Brussel"
    elif code >= 1300 and code < 1500:
        return "Brabant Wallon","Wallonia"
    elif (code >= 1500 and code < 2000) or (code >= 3000 and code < 3500):
        return "Brabant Flamand","Flanders"
    elif code >= 2000 and code < 3000:
        return "Anvers","Flanders"
    elif code >= 3500 and code < 4000:
        return "Limbourg","Flanders"
    elif code >= 4000 and code < 5000:
        return "Liège","Wallonia"
    elif code >= 5000 and code < 6000:
        return "Namur","Wallonia"
    elif (code >= 6000 and code < 6600) or (code >= 7000 and code < 8000):
        return "Hainaut","Wallonia"
    elif code >= 6600 and code < 7000:
        return "Luxembourg","Wallonia"
    elif code >= 8000 and code < 9000:
        return "Flandre Occidental","Flanders"
    elif code >= 9000:
        return "Flandre Oriental","Flanders"

# %%
data["Province"],data["Region"] = data.apply(lambda x,y: change_to_province(x,y["Locality"]), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-5f25774dc847> in <module>
# ----> 1 data["Province"],data["Region"] = data.apply(lambda x,y: change_to_province(x,y["Locality"]), axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# ...

# %%
def change_to_region(code):
    if code >= 1000 and code < 1300:
        return "Brussels"
    elif code >= 1300 and code < 1500 or :
        return "Wallonia"
    elif (code >= 1500 and code < 2000) or (code >= 3000 and code < 3500):
        return "Brabant Flamand"
    elif code >= 2000 and code < 3000:
        return "Anvers"
    elif code >= 3500 and code < 4000:
        return "Limbourg"
    elif code >= 4000 and code < 5000:
        return "Liège"
    elif code >= 5000 and code < 6000:
        return "Namur"
    elif (code >= 6000 and code < 6600) or (code >= 7000 and code < 8000):
        return "Hainaut"
    elif code >= 6600 and code < 7000:
        return "Luxembourg"
    elif code >= 8000 and code < 9000:
        return "Flandre Occidental"
    elif code >= 9000:
        return "Flandre Oriental"
# Out:
#               Source  Locality Type of property Subtype of property     Price  \
# 0      logic-immo.be      2970        apartment                 NaN  319799.0
# 1      logic-immo.be      2970        apartment                 NaN  291999.0
# 2      logic-immo.be      2970        apartment                 NaN  764999.0
# 3      logic-immo.be      2970        apartment                 NaN  660264.0
# 4      logic-immo.be      3200        apartment                 NaN  294999.0
# ...              ...       ...              ...                 ...       ...
# 73542        immoweb      8770            house                 NaN  356000.0
# 73543        immoweb      6000            house                 NaN  175000.0
# 73544        immoweb      6000            house                 NaN  185000.0
# 73545        immoweb      1480            house               villa  310442.0
# 73546        immoweb      1480            house               villa  331948.0
#
# ...

# %%
# Out:
#   File "<ipython-input-70-d4476075330d>", line 1
#     data["Commune"].apply(lambda x:["Brussel" if x >= 1000 and x < 1300])
#                                                                        ^
# SyntaxError: invalid syntax
